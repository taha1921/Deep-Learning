# %% [markdown]
# # Generative Adversarial Networks
# In this assignment, you’ll get hands-on experience coding and training GANs. This assignment is
# divided into two parts: in the first part, we will implement a specific type of GAN designed to
# process images, called a Deep Convolutional GAN (DCGAN). We’ll train the DCGAN to generate
# emojis from samples of random noise. In the second part, we will apply some methods that researchers have suggested to "stablize" the training process of GANs and then train our DCGAN again.
#
# **Note:** Please attempt this assignment on Google Colab, since that will speed up the training process.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install --upgrade opencv-python==3.4.2.17
# Out:
# Collecting opencv-python==3.4.2.17
#   Downloading https://files.pythonhosted.org/packages/53/e0/21c8964fa8ef50842ebefaa7346a3cf0e37b56c8ecd97ed6bd2dbe577705/opencv_python-3.4.2.17-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#      |████████████████████████████████| 25.0MB 128kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.17) (1.18.2)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-3.4.2.17

# %%
import numpy as np
import tensorflow as tf
import keras
import keras.backend as K
from keras.layers import Conv2D,Activation,BatchNormalization,Conv2DTranspose, Input, Flatten, Dense, Reshape, LeakyReLU, Dropout
from keras.models import Sequential, Model
from keras.optimizers import Adam, SGD, RMSprop
import os
from glob import glob
from skimage.io import imread,imshow,imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
import cv2
import math
from keras.preprocessing import image as k_image
from keras.utils.generic_utils import Progbar
from keras.initializers import RandomNormal
import random
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/My Drive/DL5/emoji_5.zip" -d "./"

# %%
ROLLNUMBER = 20100040
BATCH_SIZE = 128
IMAGE_SHAPE = [64,64]
CHANNELS = 3
NOISE_DIM = 100
EPOCHS = 1800
# Use this to prefix all your paths when reading/writing data to drive.
BASE_DIR = '/content/drive/My Drive/DL5'
# BASE_DIR = '/content/drive/My Drive/CS437 - Deep Learning/DLAS5'

# %% [markdown]
# - Here's the link to the emojis dataset: https://drive.google.com/open?id=1WRpE9SwSqguyGrrI9EP6jlHk7f1hoJMo
#
# - Here's the link to the full emojis dataset: https://drive.google.com/open?id=1UeIQIbixvapM-TBzngOwDXnHV_vv-MBG

# %% [markdown]
# ## PART 1: Deep Convolutional GAN (DCGAN)
# For the first part of this assignment, we will implement a Deep Convolutional GAN (DCGAN).
# A DCGAN is simply a GAN that uses a convolutional neural network as the discriminator, and
# a network composed of transposed convolutions as the generator. To implement the DCGAN, we
# need to specify three things: 1) the generator, 2) the discriminator, and 3) the training procedure.
# We will develop each of these three components in the following subsections.

# %%
## Helper Functions
def sample_noise():
    return np.reshape(np.random.randn(NOISE_DIM * BATCH_SIZE),(BATCH_SIZE,NOISE_DIM))

def remove_transparency(source, background_color):
    source_img = source[:, :, :3]
    source_mask = source[:, :, 3]  * (1 / 255.0)
    source_mask = np.repeat(source_mask[:, :, np.newaxis], 3, axis=2)
    background_mask = 1.0 - source_mask
    bg_part = (background_color * (1 / 255.0)) * (background_mask)
    source_part = (source_img * (1 / 255.0)) * (source_mask)
    return cv2.cvtColor(np.uint8(cv2.addWeighted(bg_part, 255.0, source_part, 255.0, 0.0)),cv2.COLOR_BGR2RGB)

def load_data():
    base_dir = 'filtered_emojis/*'
    train_files = glob(base_dir)
    train_images = np.array([cv2.resize(remove_transparency(cv2.imread(f,-1),255),tuple(IMAGE_SHAPE)) for f in train_files])
    return train_images

def create_image_grid(array, ncols=None):
    num_images, cell_h, cell_w, channels = array.shape
    if not ncols:
        ncols = int(np.sqrt(num_images))
    nrows = int(np.math.floor(num_images / float(ncols)))
    result = np.zeros((cell_h*nrows, cell_w*ncols, channels), dtype=array.dtype)
    for i in range(0, nrows):
        for j in range(0, ncols):
            result[i*cell_h:(i+1)*cell_h, j*cell_w:(j+1)*cell_w, :] = array[i*ncols+j]

    if channels == 1:
        result = result.squeeze()
    return result

# %% [markdown]
# ### Implementing the Discriminator of the DCGAN
# The discriminator in this DCGAN is a convolutional neural network that has the following architecture:
# <br>
# ![DCGAN Discriminator](DCGAN_disc.png)
# <br>

# %% [markdown]
# **Some Important points**:
# - Pass in the following arguments in your Convolutional Layers: padding='same',use_bias=False
# - After the last convolutional layer, Flatten the output and then add the final dense layer for prediction
# - Use kernel_size of (4,4), except the last one -- You may change this ((4,4) one) but don't reduce it too much
# - Reduce the spatial dimension by a factor of 2 after each convolution, except the last one.
# - Use LeakyRelu and BatchNormalization after each convolution

# %% [markdown]
# Implement the discriminator in the cell below:

# %%
def build_discriminator():
    input_disc = Input(shape=(64,64,3), name='input_disc')
    conv_1 = Conv2D(64, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(input_disc)
    leak_rel_1 = LeakyReLU()(conv_1)
    conv_2 = Conv2D(128, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_1)
    BN_1 = BatchNormalization()(conv_2)
    leak_rel_2 = LeakyReLU()(BN_1)
    conv_3 = Conv2D(256, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_2)
    BN_2 = BatchNormalization()(conv_3)
    leak_rel_3 = LeakyReLU()(BN_2)
    conv_4 = Conv2D(512, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_3)
    BN_3 = BatchNormalization()(conv_4)
    leak_rel_4 = LeakyReLU()(BN_3)
    conv_5 = Conv2D(1, kernel_size=(3,3), padding='same', use_bias=False)(leak_rel_4)
    flatten_disc = Flatten()(conv_5)
    output_disc = Dense(1, activation='sigmoid')(flatten_disc)
    disc = Model(inputs=input_disc, outputs=output_disc)
    return disc

# %% [markdown]
# ### Implementing the generator of DCGAN
# Now, we will implement the generator of the DCGAN, which consists of a sequence of transpose
# convolutional layers that progressively upsample the input noise sample to generate a fake image.
# The generator has the following architecture:
# <br>
# ![DCGAN Generator](DCGAN_gen.png)

# %% [markdown]
# **Some important points:**
# - Pass in use_bias=False,padding='same' in your convolutional layers.
# - All intermediate convolutional layers will have relu activation except the last one, which will have tanh.
# - All other properties can be inferred from the above diagram

# %% [markdown]
# Implement the generator in the cell below

# %%
def build_generator():
    input_gen = Input(shape=(100,), name='input_gen')
    dense_1 = Dense(4*4*1024)(input_gen)
    Reshape_1 = Reshape((4,4,1024),)(dense_1)
    conv_1 = Conv2DTranspose(512, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, activation='relu')(Reshape_1)
    conv_2 = Conv2DTranspose(256, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, activation='relu')(conv_1)
    conv_3 = Conv2DTranspose(128, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, activation='relu')(conv_2)
    conv_4 = Conv2DTranspose(3, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, activation='tanh')(conv_3)
    output_gen = Model(inputs = input_gen, outputs=conv_4)
    return output_gen

# %%
test_gen = build_generator()
output = test_gen.predict(sample_noise())
plt.imshow(output[1,:,:,1], cmap='gray')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# ### DCGAN Training Loop
# Next, you will implement the training loop for the DCGAN. A DCGAN is simply a GAN with a
# specific type of generator and discriminator; thus, we train it in exactly the same way as a standard
# GAN. The pseudo-code for the training procedure is shown below.

# %% [markdown]
# **Algorithm:**
# 1. Draw m training examples {x<sup>(1)</sup>,...,x<sup>(m)</sup>} from the data distribution p<sub>data</sub>.
# 2. Draw m noise samples {z<sup>(1)</sup>,...,z<sup>(m)</sup>} from the noise distribution p<sub>z</sub>.
# 3. Generate fake images from the noise: G(z<sup>(i)</sup>) for i in {1,....,m}.
# 4. Compute discriminator's loss on real images and fake images batches and then update the parameters.
# 5. Draw m NEW noise samples {z<sup>(1)</sup>,...,z<sup>(m)</sup>} from the noise distribution p<sub>z</sub>.
# 6. Generate fake images from the noise: G(z<sup>(i)</sup>) for i in {1,....,m}.
# 7. Freeze the discriminator.
# 8. Compute generator's loss then update the parameters.
# 9. Unfreeze the discriminator.

# %% [markdown]
# Before we move to writing the training loop, we will need to create a "combined" model that will attach the discriminator over the generator. This model will be used to train the generator as the discriminator will act as an adversary for the generator and force it to generate realistic images.

# %% [markdown]
# In this function below you need to create a model that:
# - Takes noise z as input (Matching the noise dimensions defined at the top of the notebook)
# - Gets a fake image generated from the generator using this noise z
# - "Freezes" the discriminator (Setting all layers of the discriminator as untrainable)
# - Outputs the output of the discriminator based on the input z.
#
# Remember to compile the model before returning it.

# %%
def build_gan(gen,disc):
    GAN = Sequential()
    GAN.add(gen)
    disc.trainable = False
    GAN.add(disc)
    GAN.compile(optimizer=Adam(lr=0.0002, beta_1=0.5), loss='binary_crossentropy')
    return GAN

# %%
test_gen = build_generator()
test_disc = build_discriminator()
test_gan = build_gan(test_gen, test_disc)
test_gan.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_59 (Model)             (None, 64, 64, 3)         18867584
# _________________________________________________________________
# model_60 (Model)             (None, 1)                 2763793
# =================================================================
# Total params: 21,631,377
# Trainable params: 18,867,584
# Non-trainable params: 2,763,793
# _________________________________________________________________

# %% [markdown]
# Write your training loop in the cell bellow. Some important points to keep in mind:
# - You need to compile the discriminator after creating an instance using build_discriminator()
# - Use the provided load_data() function to well... load the data. You can choose between generating Windows or Apple emojis
# - The entire data will be loaded as it is small enough to fit into memory (Finally no data generators, right?) BUT you still need to loop over the data in batches. Starter code is provided to you.
# - To train your models, we won't make use of <code>fit</code> instead we will use <code>train_on_batch</code> to train our model over batches. This method will return your model's loss over a particular batch, which you will use to output and store your history of losses.
# - Additionally, we will be generating samples after some epochs and storing the result on disk. The code is provided to do this.

# %%
def save_samples(generated_images,step,save_at="samples/"):
    sample_image = create_image_grid(generated_images)
    img = k_image.array_to_img(sample_image)
    img.save(os.path.join(BASE_DIR,save_at, 'generated_image_' + str(step) + '.png'))

# %%
def gan_training_loop(intervals=200):
    
    # Setup Models here
    gen = build_generator()
    disc = build_discriminator()
    # gen.compile(optimizer=Adam(lr=0.001, beta_1=0.5), loss='binary_crossentropy')
    GAN = build_gan(gen, disc)
    disc.trainable = True
    disc.compile(optimizer=Adam(lr=0.001, beta_1=0.5), loss='binary_crossentropy', metrics=['accuracy'])

    # Load Data
    X_train = load_data()
    total_size = X_train.shape[0]
    indices = np.arange(0,total_size ,BATCH_SIZE)
    all_disc_loss = []
    all_gen_loss = []
    if total_size % BATCH_SIZE:
        indices = indices[:-1]
    
    # Start Loop 
    for e in range(EPOCHS):
        progress_bar = Progbar(target=len(indices))
        np.random.shuffle(indices)
        epoch_gen_loss = []
        epoch_disc_loss = []

        # Train On Batch
        for i,index in enumerate(indices):
            # Write your code here
            fake_images = gen.predict(sample_noise())
            real_images = X_train[index:index+BATCH_SIZE]
            
            D_loss_real = disc.train_on_batch(real_images, np.ones((BATCH_SIZE, 1)))
            D_loss_fake = disc.train_on_batch(fake_images, np.zeros((BATCH_SIZE, 1)))

            if not (e % intervals):
                save_samples(fake_images,e)     
            
            disc_loss = 0.5 * np.add(D_loss_real, D_loss_fake)
            epoch_disc_loss.append(disc_loss)
            
            # Before training your generator using the combined model, freeze all layers of the discriminator first.
            # Unfreeze after your call to train_on_batch
            disc.trainable = False
            noise = sample_noise() 
            gen_loss = GAN.train_on_batch(noise, np.ones((BATCH_SIZE, 1)))
            disc.trainable = True
            epoch_gen_loss.append(gen_loss)
            progress_bar.update(i+1)
        if not (e%intervals):
            # Save weights here
            disc.save_weights(os.path.join(BASE_DIR,'discriminator'),True)
            gen.save_weights(os.path.join(BASE_DIR,'generator'),True)
            
        avg_epoch_disc_loss = np.array(epoch_disc_loss).mean()
        avg_epoch_gen_loss = np.array(epoch_gen_loss).mean()
        all_disc_loss.append(avg_epoch_disc_loss)
        all_gen_loss.append(avg_epoch_gen_loss)

        print("Epoch: %d | Discriminator Loss: %f | Generator Loss: %f" % (e+1,avg_epoch_disc_loss,avg_epoch_gen_loss))
    return all_disc_loss,all_gen_loss

# %% [markdown]
# ### Training the GAN
# We will train a DCGAN to generate fake Apple emojis. 1 epoch should take about 15 seconds on Google Colab.

# %% [markdown]
# Train your DCGAN in the below cell

# %%
disc_loss, gen_loss = gan_training_loop()
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: 1 | Discriminator Loss: 2.573045 | Generator Loss: 20.744150
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2 | Discriminator Loss: 0.558057 | Generator Loss: 9.973186
# 5/5 [==============================] - 5s 1s/step
# Epoch: 3 | Discriminator Loss: 0.526685 | Generator Loss: 10.590288
# 5/5 [==============================] - 5s 1s/step
# Epoch: 4 | Discriminator Loss: 0.515847 | Generator Loss: 10.346850
# 5/5 [==============================] - 5s 1s/step
# Epoch: 5 | Discriminator Loss: 0.514977 | Generator Loss: 9.012613
# 5/5 [==============================] - 5s 1s/step
# Epoch: 6 | Discriminator Loss: 0.513923 | Generator Loss: 8.864195
# 5/5 [==============================] - 5s 1s/step
# Epoch: 7 | Discriminator Loss: 1.091780 | Generator Loss: 11.186296
# 5/5 [==============================] - 5s 1s/step
# Epoch: 8 | Discriminator Loss: 1.434599 | Generator Loss: 4.030847
# 5/5 [==============================] - 5s 1s/step
# Epoch: 9 | Discriminator Loss: 0.643677 | Generator Loss: 4.069214
# 5/5 [==============================] - 5s 1s/step
# Epoch: 10 | Discriminator Loss: 0.623856 | Generator Loss: 4.491250
# 5/5 [==============================] - 5s 1s/step
# Epoch: 11 | Discriminator Loss: 0.612408 | Generator Loss: 4.820595
# 5/5 [==============================] - 5s 1s/step
# Epoch: 12 | Discriminator Loss: 0.737781 | Generator Loss: 8.497030
# 5/5 [==============================] - 5s 1s/step
# Epoch: 13 | Discriminator Loss: 0.928336 | Generator Loss: 3.595537
# 5/5 [==============================] - 5s 1s/step
# Epoch: 14 | Discriminator Loss: 0.634128 | Generator Loss: 4.231417
# 5/5 [==============================] - 5s 1s/step
# Epoch: 15 | Discriminator Loss: 0.636390 | Generator Loss: 5.387498
# 5/5 [==============================] - 5s 1s/step
# Epoch: 16 | Discriminator Loss: 0.611738 | Generator Loss: 5.192435
# 5/5 [==============================] - 5s 1s/step
# Epoch: 17 | Discriminator Loss: 0.642121 | Generator Loss: 6.311587
# 5/5 [==============================] - 5s 1s/step
# Epoch: 18 | Discriminator Loss: 0.636602 | Generator Loss: 5.043728
# 5/5 [==============================] - 5s 1s/step
# Epoch: 19 | Discriminator Loss: 0.952976 | Generator Loss: 5.469514
# 5/5 [==============================] - 5s 1s/step
# Epoch: 20 | Discriminator Loss: 0.775875 | Generator Loss: 3.454835
# 5/5 [==============================] - 5s 1s/step
# Epoch: 21 | Discriminator Loss: 0.643029 | Generator Loss: 3.773533
# 5/5 [==============================] - 5s 1s/step
# Epoch: 22 | Discriminator Loss: 0.640523 | Generator Loss: 4.688571
# 5/5 [==============================] - 5s 1s/step
# Epoch: 23 | Discriminator Loss: 0.649961 | Generator Loss: 4.305670
# 5/5 [==============================] - 5s 1s/step
# Epoch: 24 | Discriminator Loss: 0.648972 | Generator Loss: 4.232141
# 5/5 [==============================] - 5s 1s/step
# Epoch: 25 | Discriminator Loss: 0.614905 | Generator Loss: 4.799829
# 5/5 [==============================] - 5s 1s/step
# Epoch: 26 | Discriminator Loss: 0.697138 | Generator Loss: 4.929865
# 5/5 [==============================] - 5s 1s/step
# Epoch: 27 | Discriminator Loss: 0.694757 | Generator Loss: 3.783838
# 5/5 [==============================] - 5s 1s/step
# Epoch: 28 | Discriminator Loss: 0.644689 | Generator Loss: 4.464532
# 5/5 [==============================] - 5s 1s/step
# Epoch: 29 | Discriminator Loss: 0.671220 | Generator Loss: 4.029521
# 5/5 [==============================] - 5s 1s/step
# Epoch: 30 | Discriminator Loss: 0.623356 | Generator Loss: 4.832099
# 5/5 [==============================] - 5s 1s/step
# Epoch: 31 | Discriminator Loss: 0.643369 | Generator Loss: 4.645796
# 5/5 [==============================] - 5s 1s/step
# Epoch: 32 | Discriminator Loss: 0.675986 | Generator Loss: 4.653878
# 5/5 [==============================] - 5s 1s/step
# Epoch: 33 | Discriminator Loss: 0.652079 | Generator Loss: 4.446097
# 5/5 [==============================] - 5s 1s/step
# Epoch: 34 | Discriminator Loss: 0.636792 | Generator Loss: 5.388051
# 5/5 [==============================] - 5s 1s/step
# Epoch: 35 | Discriminator Loss: 0.789160 | Generator Loss: 4.349146
# 5/5 [==============================] - 5s 1s/step
# Epoch: 36 | Discriminator Loss: 0.612834 | Generator Loss: 3.835297
# 5/5 [==============================] - 5s 1s/step
# Epoch: 37 | Discriminator Loss: 0.588146 | Generator Loss: 4.774850
# 5/5 [==============================] - 5s 1s/step
# Epoch: 38 | Discriminator Loss: 0.590246 | Generator Loss: 6.802972
# 5/5 [==============================] - 5s 1s/step
# Epoch: 39 | Discriminator Loss: 0.633115 | Generator Loss: 5.800311
# 5/5 [==============================] - 5s 1s/step
# Epoch: 40 | Discriminator Loss: 0.786880 | Generator Loss: 4.668797
# 5/5 [==============================] - 5s 1s/step
# Epoch: 41 | Discriminator Loss: 0.603003 | Generator Loss: 5.049444
# 5/5 [==============================] - 5s 1s/step
# Epoch: 42 | Discriminator Loss: 0.638682 | Generator Loss: 6.543086
# 5/5 [==============================] - 5s 1s/step
# Epoch: 43 | Discriminator Loss: 0.724619 | Generator Loss: 3.377270
# 5/5 [==============================] - 5s 1s/step
# Epoch: 44 | Discriminator Loss: 0.639777 | Generator Loss: 4.027276
# 5/5 [==============================] - 5s 1s/step
# Epoch: 45 | Discriminator Loss: 0.633818 | Generator Loss: 4.374648
# 5/5 [==============================] - 5s 1s/step
# Epoch: 46 | Discriminator Loss: 0.582917 | Generator Loss: 5.068502
# 5/5 [==============================] - 5s 1s/step
# Epoch: 47 | Discriminator Loss: 0.552212 | Generator Loss: 5.282879
# 5/5 [==============================] - 5s 1s/step
# Epoch: 48 | Discriminator Loss: 0.603633 | Generator Loss: 8.527460
# 5/5 [==============================] - 5s 1s/step
# Epoch: 49 | Discriminator Loss: 0.531945 | Generator Loss: 5.775645
# 5/5 [==============================] - 5s 1s/step
# Epoch: 50 | Discriminator Loss: 0.540346 | Generator Loss: 5.202633
# 5/5 [==============================] - 5s 1s/step
# Epoch: 51 | Discriminator Loss: 0.523395 | Generator Loss: 6.015680
# 5/5 [==============================] - 5s 1s/step
# Epoch: 52 | Discriminator Loss: 0.512317 | Generator Loss: 6.084132
# 5/5 [==============================] - 5s 1s/step
# Epoch: 53 | Discriminator Loss: 0.509999 | Generator Loss: 4.882099
# 5/5 [==============================] - 5s 1s/step
# Epoch: 54 | Discriminator Loss: 0.512314 | Generator Loss: 5.465621
# 5/5 [==============================] - 5s 1s/step
# Epoch: 55 | Discriminator Loss: 0.511877 | Generator Loss: 9.777701
# 5/5 [==============================] - 5s 1s/step
# Epoch: 56 | Discriminator Loss: 0.505036 | Generator Loss: 5.338907
# 5/5 [==============================] - 5s 1s/step
# Epoch: 57 | Discriminator Loss: 0.510526 | Generator Loss: 6.175645
# 5/5 [==============================] - 5s 1s/step
# Epoch: 58 | Discriminator Loss: 0.516750 | Generator Loss: 7.426729
# 5/5 [==============================] - 5s 1s/step
# Epoch: 59 | Discriminator Loss: 1.922094 | Generator Loss: 9.403617
# 5/5 [==============================] - 5s 1s/step
# Epoch: 60 | Discriminator Loss: 0.588272 | Generator Loss: 2.826645
# 5/5 [==============================] - 5s 1s/step
# Epoch: 61 | Discriminator Loss: 0.721362 | Generator Loss: 4.314964
# 5/5 [==============================] - 5s 1s/step
# Epoch: 62 | Discriminator Loss: 0.616318 | Generator Loss: 4.957326
# 5/5 [==============================] - 5s 1s/step
# Epoch: 63 | Discriminator Loss: 0.538910 | Generator Loss: 6.036698
# 5/5 [==============================] - 5s 1s/step
# Epoch: 64 | Discriminator Loss: 0.666609 | Generator Loss: 5.148643
# 5/5 [==============================] - 5s 1s/step
# Epoch: 65 | Discriminator Loss: 0.542640 | Generator Loss: 4.290826
# 5/5 [==============================] - 5s 1s/step
# Epoch: 66 | Discriminator Loss: 0.522803 | Generator Loss: 5.266116
# 5/5 [==============================] - 5s 1s/step
# Epoch: 67 | Discriminator Loss: 0.519646 | Generator Loss: 4.901610
# 5/5 [==============================] - 5s 1s/step
# Epoch: 68 | Discriminator Loss: 0.513499 | Generator Loss: 4.793134
# 5/5 [==============================] - 5s 1s/step
# Epoch: 69 | Discriminator Loss: 0.513695 | Generator Loss: 4.466243
# 5/5 [==============================] - 5s 1s/step
# Epoch: 70 | Discriminator Loss: 0.517477 | Generator Loss: 4.038117
# 5/5 [==============================] - 5s 1s/step
# Epoch: 71 | Discriminator Loss: 0.520785 | Generator Loss: 4.090123
# 5/5 [==============================] - 5s 1s/step
# Epoch: 72 | Discriminator Loss: 0.516450 | Generator Loss: 3.762243
# 5/5 [==============================] - 5s 1s/step
# Epoch: 73 | Discriminator Loss: 0.516126 | Generator Loss: 4.333633
# 5/5 [==============================] - 5s 1s/step
# Epoch: 74 | Discriminator Loss: 0.612904 | Generator Loss: 5.283218
# 5/5 [==============================] - 5s 1s/step
# Epoch: 75 | Discriminator Loss: 0.727224 | Generator Loss: 6.002935
# 5/5 [==============================] - 5s 1s/step
# Epoch: 76 | Discriminator Loss: 0.828308 | Generator Loss: 2.853257
# 5/5 [==============================] - 5s 1s/step
# Epoch: 77 | Discriminator Loss: 0.588059 | Generator Loss: 4.574271
# 5/5 [==============================] - 5s 1s/step
# Epoch: 78 | Discriminator Loss: 0.521845 | Generator Loss: 4.908970
# 5/5 [==============================] - 5s 1s/step
# Epoch: 79 | Discriminator Loss: 0.526673 | Generator Loss: 4.080703
# 5/5 [==============================] - 5s 1s/step
# Epoch: 80 | Discriminator Loss: 0.544398 | Generator Loss: 4.256946
# 5/5 [==============================] - 5s 1s/step
# Epoch: 81 | Discriminator Loss: 0.522029 | Generator Loss: 3.868707
# 5/5 [==============================] - 5s 1s/step
# Epoch: 82 | Discriminator Loss: 0.510376 | Generator Loss: 4.281937
# 5/5 [==============================] - 5s 1s/step
# Epoch: 83 | Discriminator Loss: 0.508443 | Generator Loss: 4.123303
# 5/5 [==============================] - 5s 1s/step
# Epoch: 84 | Discriminator Loss: 0.506956 | Generator Loss: 4.161287
# 5/5 [==============================] - 5s 1s/step
# Epoch: 85 | Discriminator Loss: 0.506530 | Generator Loss: 4.262416
# 5/5 [==============================] - 5s 1s/step
# Epoch: 86 | Discriminator Loss: 0.505596 | Generator Loss: 4.589499
# 5/5 [==============================] - 5s 1s/step
# Epoch: 87 | Discriminator Loss: 0.502936 | Generator Loss: 4.838970
# 5/5 [==============================] - 5s 1s/step
# Epoch: 88 | Discriminator Loss: 0.503744 | Generator Loss: 4.498377
# 5/5 [==============================] - 5s 1s/step
# Epoch: 89 | Discriminator Loss: 0.502129 | Generator Loss: 5.793494
# 5/5 [==============================] - 5s 1s/step
# Epoch: 90 | Discriminator Loss: 0.503637 | Generator Loss: 4.706791
# 5/5 [==============================] - 5s 1s/step
# Epoch: 91 | Discriminator Loss: 0.507089 | Generator Loss: 4.447041
# 5/5 [==============================] - 5s 1s/step
# Epoch: 92 | Discriminator Loss: 0.514068 | Generator Loss: 4.287743
# 5/5 [==============================] - 5s 1s/step
# Epoch: 93 | Discriminator Loss: 1.115022 | Generator Loss: 6.351243
# 5/5 [==============================] - 5s 1s/step
# Epoch: 94 | Discriminator Loss: 0.614239 | Generator Loss: 3.706127
# 5/5 [==============================] - 5s 1s/step
# Epoch: 95 | Discriminator Loss: 0.671894 | Generator Loss: 4.138323
# 5/5 [==============================] - 5s 1s/step
# Epoch: 96 | Discriminator Loss: 0.613208 | Generator Loss: 4.715239
# 5/5 [==============================] - 5s 1s/step
# Epoch: 97 | Discriminator Loss: 0.549668 | Generator Loss: 8.426689
# 5/5 [==============================] - 5s 1s/step
# Epoch: 98 | Discriminator Loss: 0.519162 | Generator Loss: 7.812054
# 5/5 [==============================] - 5s 1s/step
# Epoch: 99 | Discriminator Loss: 0.540252 | Generator Loss: 5.291821
# 5/5 [==============================] - 5s 1s/step
# Epoch: 100 | Discriminator Loss: 0.515180 | Generator Loss: 5.817108
# 5/5 [==============================] - 5s 1s/step
# Epoch: 101 | Discriminator Loss: 0.510859 | Generator Loss: 6.868796
# 5/5 [==============================] - 5s 1s/step
# Epoch: 102 | Discriminator Loss: 0.514970 | Generator Loss: 6.901115
# 5/5 [==============================] - 5s 1s/step
# Epoch: 103 | Discriminator Loss: 0.508046 | Generator Loss: 6.731357
# 5/5 [==============================] - 5s 1s/step
# Epoch: 104 | Discriminator Loss: 0.537132 | Generator Loss: 8.585953
# 5/5 [==============================] - 5s 1s/step
# Epoch: 105 | Discriminator Loss: 0.996550 | Generator Loss: 8.322228
# 5/5 [==============================] - 5s 1s/step
# Epoch: 106 | Discriminator Loss: 0.532350 | Generator Loss: 7.696067
# 5/5 [==============================] - 5s 1s/step
# Epoch: 107 | Discriminator Loss: 0.510183 | Generator Loss: 9.525820
# 5/5 [==============================] - 5s 1s/step
# Epoch: 108 | Discriminator Loss: 0.501410 | Generator Loss: 6.939880
# 5/5 [==============================] - 5s 1s/step
# Epoch: 109 | Discriminator Loss: 0.502250 | Generator Loss: 5.587642
# 5/5 [==============================] - 5s 1s/step
# Epoch: 110 | Discriminator Loss: 0.503339 | Generator Loss: 5.204554
# 5/5 [==============================] - 5s 1s/step
# Epoch: 111 | Discriminator Loss: 0.542025 | Generator Loss: 6.154289
# 5/5 [==============================] - 5s 1s/step
# Epoch: 112 | Discriminator Loss: 0.530219 | Generator Loss: 7.000594
# 5/5 [==============================] - 5s 1s/step
# Epoch: 113 | Discriminator Loss: 0.511419 | Generator Loss: 5.859467
# 5/5 [==============================] - 5s 1s/step
# Epoch: 114 | Discriminator Loss: 0.511297 | Generator Loss: 5.246299
# 5/5 [==============================] - 5s 1s/step
# Epoch: 115 | Discriminator Loss: 0.508513 | Generator Loss: 6.339330
# 5/5 [==============================] - 5s 1s/step
# Epoch: 116 | Discriminator Loss: 0.508497 | Generator Loss: 5.181018
# 5/5 [==============================] - 5s 1s/step
# Epoch: 117 | Discriminator Loss: 0.508768 | Generator Loss: 5.080492
# 5/5 [==============================] - 5s 1s/step
# Epoch: 118 | Discriminator Loss: 0.509409 | Generator Loss: 4.981915
# 5/5 [==============================] - 5s 1s/step
# Epoch: 119 | Discriminator Loss: 0.508647 | Generator Loss: 5.359210
# 5/5 [==============================] - 5s 1s/step
# Epoch: 120 | Discriminator Loss: 0.511952 | Generator Loss: 6.977760
# 5/5 [==============================] - 5s 1s/step
# Epoch: 121 | Discriminator Loss: 0.503216 | Generator Loss: 6.954193
# 5/5 [==============================] - 5s 1s/step
# Epoch: 122 | Discriminator Loss: 0.511056 | Generator Loss: 4.821250
# 5/5 [==============================] - 5s 1s/step
# Epoch: 123 | Discriminator Loss: 0.516991 | Generator Loss: 5.144237
# 5/5 [==============================] - 5s 1s/step
# Epoch: 124 | Discriminator Loss: 1.074456 | Generator Loss: 4.683036
# 5/5 [==============================] - 5s 1s/step
# Epoch: 125 | Discriminator Loss: 1.089557 | Generator Loss: 5.703113
# 5/5 [==============================] - 5s 1s/step
# Epoch: 126 | Discriminator Loss: 0.781766 | Generator Loss: 3.511700
# 5/5 [==============================] - 5s 1s/step
# Epoch: 127 | Discriminator Loss: 0.676940 | Generator Loss: 3.231099
# 5/5 [==============================] - 5s 1s/step
# Epoch: 128 | Discriminator Loss: 0.934811 | Generator Loss: 3.475030
# 5/5 [==============================] - 5s 1s/step
# Epoch: 129 | Discriminator Loss: 0.676664 | Generator Loss: 2.556531
# 5/5 [==============================] - 5s 1s/step
# Epoch: 130 | Discriminator Loss: 0.675498 | Generator Loss: 3.028027
# 5/5 [==============================] - 5s 1s/step
# Epoch: 131 | Discriminator Loss: 0.650160 | Generator Loss: 2.664721
# 5/5 [==============================] - 5s 1s/step
# Epoch: 132 | Discriminator Loss: 0.732276 | Generator Loss: 2.588960
# 5/5 [==============================] - 5s 1s/step
# Epoch: 133 | Discriminator Loss: 0.690277 | Generator Loss: 2.882898
# 5/5 [==============================] - 5s 1s/step
# Epoch: 134 | Discriminator Loss: 0.646181 | Generator Loss: 2.302783
# 5/5 [==============================] - 5s 1s/step
# Epoch: 135 | Discriminator Loss: 0.604379 | Generator Loss: 2.709065
# 5/5 [==============================] - 5s 1s/step
# Epoch: 136 | Discriminator Loss: 0.614206 | Generator Loss: 3.146411
# 5/5 [==============================] - 5s 1s/step
# Epoch: 137 | Discriminator Loss: 0.797686 | Generator Loss: 3.547003
# 5/5 [==============================] - 5s 1s/step
# Epoch: 138 | Discriminator Loss: 0.586155 | Generator Loss: 2.971420
# 5/5 [==============================] - 5s 1s/step
# Epoch: 139 | Discriminator Loss: 0.624322 | Generator Loss: 2.721802
# 5/5 [==============================] - 5s 1s/step
# Epoch: 140 | Discriminator Loss: 0.687566 | Generator Loss: 3.518046
# 5/5 [==============================] - 5s 1s/step
# Epoch: 141 | Discriminator Loss: 0.679323 | Generator Loss: 2.199244
# 5/5 [==============================] - 5s 1s/step
# Epoch: 142 | Discriminator Loss: 0.626276 | Generator Loss: 1.734113
# 5/5 [==============================] - 5s 1s/step
# Epoch: 143 | Discriminator Loss: 0.618864 | Generator Loss: 1.541763
# 5/5 [==============================] - 5s 1s/step
# Epoch: 144 | Discriminator Loss: 0.624490 | Generator Loss: 1.753154
# 5/5 [==============================] - 5s 1s/step
# Epoch: 145 | Discriminator Loss: 0.619471 | Generator Loss: 1.890424
# 5/5 [==============================] - 5s 1s/step
# Epoch: 146 | Discriminator Loss: 0.622108 | Generator Loss: 1.778802
# 5/5 [==============================] - 5s 1s/step
# Epoch: 147 | Discriminator Loss: 0.615202 | Generator Loss: 1.817303
# 5/5 [==============================] - 5s 1s/step
# Epoch: 148 | Discriminator Loss: 0.637148 | Generator Loss: 1.913079
# 5/5 [==============================] - 5s 1s/step
# Epoch: 149 | Discriminator Loss: 0.628827 | Generator Loss: 2.013794
# 5/5 [==============================] - 5s 1s/step
# Epoch: 150 | Discriminator Loss: 0.638321 | Generator Loss: 2.062134
# 5/5 [==============================] - 5s 1s/step
# Epoch: 151 | Discriminator Loss: 0.636939 | Generator Loss: 2.471159
# 5/5 [==============================] - 5s 1s/step
# Epoch: 152 | Discriminator Loss: 0.620897 | Generator Loss: 2.274552
# 5/5 [==============================] - 5s 1s/step
# Epoch: 153 | Discriminator Loss: 0.616899 | Generator Loss: 2.630260
# 5/5 [==============================] - 5s 1s/step
# Epoch: 154 | Discriminator Loss: 0.601529 | Generator Loss: 3.089615
# 5/5 [==============================] - 5s 1s/step
# Epoch: 155 | Discriminator Loss: 0.704030 | Generator Loss: 3.236757
# 5/5 [==============================] - 5s 1s/step
# Epoch: 156 | Discriminator Loss: 0.701881 | Generator Loss: 2.181837
# 5/5 [==============================] - 5s 1s/step
# Epoch: 157 | Discriminator Loss: 0.658528 | Generator Loss: 2.268969
# 5/5 [==============================] - 5s 1s/step
# Epoch: 158 | Discriminator Loss: 0.642819 | Generator Loss: 2.388474
# 5/5 [==============================] - 5s 1s/step
# Epoch: 159 | Discriminator Loss: 0.645700 | Generator Loss: 2.288617
# 5/5 [==============================] - 5s 1s/step
# Epoch: 160 | Discriminator Loss: 0.647861 | Generator Loss: 2.837915
# 5/5 [==============================] - 5s 1s/step
# Epoch: 161 | Discriminator Loss: 0.617164 | Generator Loss: 2.880014
# 5/5 [==============================] - 5s 1s/step
# Epoch: 162 | Discriminator Loss: 0.660078 | Generator Loss: 2.982132
# 5/5 [==============================] - 5s 1s/step
# Epoch: 163 | Discriminator Loss: 0.629765 | Generator Loss: 2.488728
# 5/5 [==============================] - 5s 1s/step
# Epoch: 164 | Discriminator Loss: 0.661276 | Generator Loss: 1.921340
# 5/5 [==============================] - 5s 1s/step
# Epoch: 165 | Discriminator Loss: 0.634570 | Generator Loss: 2.548653
# 5/5 [==============================] - 5s 1s/step
# Epoch: 166 | Discriminator Loss: 0.633953 | Generator Loss: 2.333459
# 5/5 [==============================] - 5s 1s/step
# Epoch: 167 | Discriminator Loss: 0.635703 | Generator Loss: 2.626628
# 5/5 [==============================] - 5s 1s/step
# Epoch: 168 | Discriminator Loss: 0.630841 | Generator Loss: 2.774706
# 5/5 [==============================] - 5s 1s/step
# Epoch: 169 | Discriminator Loss: 0.634895 | Generator Loss: 3.073924
# 5/5 [==============================] - 5s 1s/step
# Epoch: 170 | Discriminator Loss: 0.659941 | Generator Loss: 2.703383
# 5/5 [==============================] - 5s 1s/step
# Epoch: 171 | Discriminator Loss: 0.669557 | Generator Loss: 3.064332
# 5/5 [==============================] - 5s 1s/step
# Epoch: 172 | Discriminator Loss: 0.636593 | Generator Loss: 2.652787
# 5/5 [==============================] - 5s 1s/step
# Epoch: 173 | Discriminator Loss: 0.619930 | Generator Loss: 3.179980
# 5/5 [==============================] - 5s 1s/step
# Epoch: 174 | Discriminator Loss: 0.612533 | Generator Loss: 3.077689
# 5/5 [==============================] - 5s 1s/step
# Epoch: 175 | Discriminator Loss: 0.620996 | Generator Loss: 3.207000
# 5/5 [==============================] - 5s 1s/step
# Epoch: 176 | Discriminator Loss: 0.667367 | Generator Loss: 3.895480
# 5/5 [==============================] - 5s 1s/step
# Epoch: 177 | Discriminator Loss: 0.598669 | Generator Loss: 3.324653
# 5/5 [==============================] - 5s 1s/step
# Epoch: 178 | Discriminator Loss: 0.700512 | Generator Loss: 3.617880
# 5/5 [==============================] - 5s 1s/step
# Epoch: 179 | Discriminator Loss: 0.645604 | Generator Loss: 3.046679
# 5/5 [==============================] - 5s 1s/step
# Epoch: 180 | Discriminator Loss: 0.626294 | Generator Loss: 3.410054
# 5/5 [==============================] - 5s 1s/step
# Epoch: 181 | Discriminator Loss: 0.640718 | Generator Loss: 2.957105
# 5/5 [==============================] - 5s 1s/step
# Epoch: 182 | Discriminator Loss: 0.627403 | Generator Loss: 3.207391
# 5/5 [==============================] - 5s 1s/step
# Epoch: 183 | Discriminator Loss: 0.622175 | Generator Loss: 3.297691
# 5/5 [==============================] - 5s 1s/step
# Epoch: 184 | Discriminator Loss: 0.606040 | Generator Loss: 3.600352
# 5/5 [==============================] - 5s 1s/step
# Epoch: 185 | Discriminator Loss: 0.572929 | Generator Loss: 3.730767
# 5/5 [==============================] - 5s 1s/step
# Epoch: 186 | Discriminator Loss: 0.570309 | Generator Loss: 4.103264
# 5/5 [==============================] - 5s 1s/step
# Epoch: 187 | Discriminator Loss: 0.546151 | Generator Loss: 3.913105
# 5/5 [==============================] - 5s 1s/step
# Epoch: 188 | Discriminator Loss: 0.568871 | Generator Loss: 4.335688
# 5/5 [==============================] - 5s 1s/step
# Epoch: 189 | Discriminator Loss: 0.551362 | Generator Loss: 4.070222
# 5/5 [==============================] - 5s 1s/step
# Epoch: 190 | Discriminator Loss: 1.009964 | Generator Loss: 3.892587
# 5/5 [==============================] - 5s 1s/step
# Epoch: 191 | Discriminator Loss: 0.636256 | Generator Loss: 2.682062
# 5/5 [==============================] - 5s 1s/step
# Epoch: 192 | Discriminator Loss: 0.598569 | Generator Loss: 3.421268
# 5/5 [==============================] - 5s 1s/step
# Epoch: 193 | Discriminator Loss: 0.597769 | Generator Loss: 3.770124
# 5/5 [==============================] - 5s 1s/step
# Epoch: 194 | Discriminator Loss: 0.628438 | Generator Loss: 4.117705
# 5/5 [==============================] - 5s 1s/step
# Epoch: 195 | Discriminator Loss: 0.662771 | Generator Loss: 4.248096
# 5/5 [==============================] - 5s 1s/step
# Epoch: 196 | Discriminator Loss: 0.676170 | Generator Loss: 2.618635
# 5/5 [==============================] - 5s 1s/step
# Epoch: 197 | Discriminator Loss: 0.629156 | Generator Loss: 3.011500
# 5/5 [==============================] - 5s 1s/step
# Epoch: 198 | Discriminator Loss: 0.612652 | Generator Loss: 3.413048
# 5/5 [==============================] - 5s 1s/step
# Epoch: 199 | Discriminator Loss: 0.562191 | Generator Loss: 3.068913
# 5/5 [==============================] - 5s 1s/step
# Epoch: 200 | Discriminator Loss: 0.541993 | Generator Loss: 3.303760
# 5/5 [==============================] - 6s 1s/step
# Epoch: 201 | Discriminator Loss: 0.595294 | Generator Loss: 3.715069
# 5/5 [==============================] - 5s 1s/step
# Epoch: 202 | Discriminator Loss: 0.777067 | Generator Loss: 4.078343
# 5/5 [==============================] - 5s 1s/step
# Epoch: 203 | Discriminator Loss: 0.714642 | Generator Loss: 2.287376
# 5/5 [==============================] - 5s 1s/step
# Epoch: 204 | Discriminator Loss: 0.635806 | Generator Loss: 2.037666
# 5/5 [==============================] - 5s 1s/step
# Epoch: 205 | Discriminator Loss: 0.642352 | Generator Loss: 2.518191
# 5/5 [==============================] - 5s 1s/step
# Epoch: 206 | Discriminator Loss: 0.631174 | Generator Loss: 2.490695
# 5/5 [==============================] - 5s 1s/step
# Epoch: 207 | Discriminator Loss: 0.627049 | Generator Loss: 2.885998
# 5/5 [==============================] - 5s 1s/step
# Epoch: 208 | Discriminator Loss: 0.666070 | Generator Loss: 2.773629
# 5/5 [==============================] - 5s 1s/step
# Epoch: 209 | Discriminator Loss: 0.624545 | Generator Loss: 2.654482
# 5/5 [==============================] - 5s 1s/step
# Epoch: 210 | Discriminator Loss: 0.661633 | Generator Loss: 3.219841
# 5/5 [==============================] - 5s 1s/step
# Epoch: 211 | Discriminator Loss: 0.679548 | Generator Loss: 3.151150
# 5/5 [==============================] - 5s 1s/step
# Epoch: 212 | Discriminator Loss: 0.653017 | Generator Loss: 3.118228
# 5/5 [==============================] - 5s 1s/step
# Epoch: 213 | Discriminator Loss: 0.632887 | Generator Loss: 2.680898
# 5/5 [==============================] - 5s 1s/step
# Epoch: 214 | Discriminator Loss: 0.644677 | Generator Loss: 2.598661
# 5/5 [==============================] - 5s 1s/step
# Epoch: 215 | Discriminator Loss: 0.571154 | Generator Loss: 3.317231
# 5/5 [==============================] - 5s 1s/step
# Epoch: 216 | Discriminator Loss: 0.541867 | Generator Loss: 3.441640
# 5/5 [==============================] - 5s 1s/step
# Epoch: 217 | Discriminator Loss: 0.550119 | Generator Loss: 3.792152
# 5/5 [==============================] - 5s 1s/step
# Epoch: 218 | Discriminator Loss: 0.541086 | Generator Loss: 4.036918
# 5/5 [==============================] - 5s 1s/step
# Epoch: 219 | Discriminator Loss: 0.733477 | Generator Loss: 4.548508
# 5/5 [==============================] - 5s 1s/step
# Epoch: 220 | Discriminator Loss: 0.643168 | Generator Loss: 3.291734
# 5/5 [==============================] - 5s 1s/step
# Epoch: 221 | Discriminator Loss: 0.595556 | Generator Loss: 3.789351
# 5/5 [==============================] - 5s 1s/step
# Epoch: 222 | Discriminator Loss: 0.764006 | Generator Loss: 3.092799
# 5/5 [==============================] - 5s 1s/step
# Epoch: 223 | Discriminator Loss: 0.656141 | Generator Loss: 3.582113
# 5/5 [==============================] - 5s 1s/step
# Epoch: 224 | Discriminator Loss: 0.607057 | Generator Loss: 2.702353
# 5/5 [==============================] - 5s 1s/step
# Epoch: 225 | Discriminator Loss: 0.651190 | Generator Loss: 3.100607
# 5/5 [==============================] - 5s 1s/step
# Epoch: 226 | Discriminator Loss: 0.634565 | Generator Loss: 3.521637
# 5/5 [==============================] - 5s 1s/step
# Epoch: 227 | Discriminator Loss: 0.638826 | Generator Loss: 3.686810
# 5/5 [==============================] - 5s 1s/step
# Epoch: 228 | Discriminator Loss: 0.573604 | Generator Loss: 3.641692
# 5/5 [==============================] - 5s 1s/step
# Epoch: 229 | Discriminator Loss: 0.601870 | Generator Loss: 3.863946
# 5/5 [==============================] - 5s 1s/step
# Epoch: 230 | Discriminator Loss: 0.673392 | Generator Loss: 4.021808
# 5/5 [==============================] - 5s 1s/step
# Epoch: 231 | Discriminator Loss: 0.608811 | Generator Loss: 3.131031
# 5/5 [==============================] - 5s 1s/step
# Epoch: 232 | Discriminator Loss: 0.549259 | Generator Loss: 3.727193
# 5/5 [==============================] - 5s 1s/step
# Epoch: 233 | Discriminator Loss: 0.597091 | Generator Loss: 4.868387
# 5/5 [==============================] - 5s 1s/step
# Epoch: 234 | Discriminator Loss: 0.610935 | Generator Loss: 3.808074
# 5/5 [==============================] - 5s 1s/step
# Epoch: 235 | Discriminator Loss: 0.586933 | Generator Loss: 4.202662
# 5/5 [==============================] - 5s 1s/step
# Epoch: 236 | Discriminator Loss: 0.561460 | Generator Loss: 4.011515
# 5/5 [==============================] - 5s 1s/step
# Epoch: 237 | Discriminator Loss: 0.635365 | Generator Loss: 5.649847
# 5/5 [==============================] - 5s 1s/step
# Epoch: 238 | Discriminator Loss: 0.659361 | Generator Loss: 3.035868
# 5/5 [==============================] - 5s 1s/step
# Epoch: 239 | Discriminator Loss: 0.613037 | Generator Loss: 4.207422
# 5/5 [==============================] - 5s 1s/step
# Epoch: 240 | Discriminator Loss: 0.562710 | Generator Loss: 3.679076
# 5/5 [==============================] - 5s 1s/step
# Epoch: 241 | Discriminator Loss: 0.566881 | Generator Loss: 4.690911
# 5/5 [==============================] - 5s 1s/step
# Epoch: 242 | Discriminator Loss: 0.615373 | Generator Loss: 4.371082
# 5/5 [==============================] - 5s 1s/step
# Epoch: 243 | Discriminator Loss: 0.623478 | Generator Loss: 4.056048
# 5/5 [==============================] - 5s 1s/step
# Epoch: 244 | Discriminator Loss: 0.617575 | Generator Loss: 3.695266
# 5/5 [==============================] - 5s 1s/step
# Epoch: 245 | Discriminator Loss: 0.637901 | Generator Loss: 4.845864
# 5/5 [==============================] - 5s 1s/step
# Epoch: 246 | Discriminator Loss: 0.711267 | Generator Loss: 3.627464
# 5/5 [==============================] - 5s 1s/step
# Epoch: 247 | Discriminator Loss: 0.755997 | Generator Loss: 3.290424
# 5/5 [==============================] - 5s 1s/step
# Epoch: 248 | Discriminator Loss: 0.612937 | Generator Loss: 3.601974
# 5/5 [==============================] - 5s 1s/step
# Epoch: 249 | Discriminator Loss: 0.558123 | Generator Loss: 3.686171
# 5/5 [==============================] - 5s 1s/step
# Epoch: 250 | Discriminator Loss: 0.536186 | Generator Loss: 3.921785
# 5/5 [==============================] - 5s 1s/step
# Epoch: 251 | Discriminator Loss: 0.545290 | Generator Loss: 5.046093
# 5/5 [==============================] - 5s 1s/step
# Epoch: 252 | Discriminator Loss: 0.582592 | Generator Loss: 7.074782
# 5/5 [==============================] - 5s 1s/step
# Epoch: 253 | Discriminator Loss: 0.764266 | Generator Loss: 5.140251
# 5/5 [==============================] - 5s 1s/step
# Epoch: 254 | Discriminator Loss: 0.664207 | Generator Loss: 3.075461
# 5/5 [==============================] - 5s 1s/step
# Epoch: 255 | Discriminator Loss: 0.637961 | Generator Loss: 3.162277
# 5/5 [==============================] - 5s 1s/step
# Epoch: 256 | Discriminator Loss: 0.669377 | Generator Loss: 2.982332
# 5/5 [==============================] - 5s 1s/step
# Epoch: 257 | Discriminator Loss: 0.620107 | Generator Loss: 3.253974
# 5/5 [==============================] - 5s 1s/step
# Epoch: 258 | Discriminator Loss: 0.605405 | Generator Loss: 3.447794
# 5/5 [==============================] - 5s 1s/step
# Epoch: 259 | Discriminator Loss: 0.605917 | Generator Loss: 4.336508
# 5/5 [==============================] - 5s 1s/step
# Epoch: 260 | Discriminator Loss: 0.589899 | Generator Loss: 3.269323
# 5/5 [==============================] - 5s 1s/step
# Epoch: 261 | Discriminator Loss: 0.585283 | Generator Loss: 4.438975
# 5/5 [==============================] - 5s 1s/step
# Epoch: 262 | Discriminator Loss: 0.569140 | Generator Loss: 4.822580
# 5/5 [==============================] - 5s 1s/step
# Epoch: 263 | Discriminator Loss: 0.543111 | Generator Loss: 4.949864
# 5/5 [==============================] - 5s 1s/step
# Epoch: 264 | Discriminator Loss: 1.110728 | Generator Loss: 5.442210
# 5/5 [==============================] - 5s 1s/step
# Epoch: 265 | Discriminator Loss: 0.569597 | Generator Loss: 3.053924
# 5/5 [==============================] - 5s 1s/step
# Epoch: 266 | Discriminator Loss: 0.552212 | Generator Loss: 3.612787
# 5/5 [==============================] - 5s 1s/step
# Epoch: 267 | Discriminator Loss: 0.526811 | Generator Loss: 3.908642
# 5/5 [==============================] - 5s 1s/step
# Epoch: 268 | Discriminator Loss: 0.545649 | Generator Loss: 4.805944
# 5/5 [==============================] - 5s 1s/step
# Epoch: 269 | Discriminator Loss: 0.519035 | Generator Loss: 5.409985
# 5/5 [==============================] - 5s 1s/step
# Epoch: 270 | Discriminator Loss: 0.514094 | Generator Loss: 5.053174
# 5/5 [==============================] - 5s 1s/step
# Epoch: 271 | Discriminator Loss: 0.514908 | Generator Loss: 4.625224
# 5/5 [==============================] - 5s 1s/step
# Epoch: 272 | Discriminator Loss: 0.511747 | Generator Loss: 4.879402
# 5/5 [==============================] - 5s 1s/step
# Epoch: 273 | Discriminator Loss: 0.507634 | Generator Loss: 5.116449
# 5/5 [==============================] - 5s 1s/step
# Epoch: 274 | Discriminator Loss: 0.508212 | Generator Loss: 4.975509
# 5/5 [==============================] - 5s 1s/step
# Epoch: 275 | Discriminator Loss: 0.506532 | Generator Loss: 4.905009
# 5/5 [==============================] - 5s 1s/step
# Epoch: 276 | Discriminator Loss: 0.509294 | Generator Loss: 4.383383
# 5/5 [==============================] - 5s 1s/step
# Epoch: 277 | Discriminator Loss: 0.506730 | Generator Loss: 5.026535
# 5/5 [==============================] - 5s 1s/step
# Epoch: 278 | Discriminator Loss: 0.505717 | Generator Loss: 5.323377
# 5/5 [==============================] - 5s 1s/step
# Epoch: 279 | Discriminator Loss: 0.506839 | Generator Loss: 4.225936
# 5/5 [==============================] - 5s 1s/step
# Epoch: 280 | Discriminator Loss: 0.504271 | Generator Loss: 5.350293
# 5/5 [==============================] - 5s 1s/step
# Epoch: 281 | Discriminator Loss: 0.503527 | Generator Loss: 5.048614
# 5/5 [==============================] - 5s 1s/step
# Epoch: 282 | Discriminator Loss: 0.507562 | Generator Loss: 4.367440
# 5/5 [==============================] - 5s 1s/step
# Epoch: 283 | Discriminator Loss: 0.506089 | Generator Loss: 4.224765
# 5/5 [==============================] - 5s 1s/step
# Epoch: 284 | Discriminator Loss: 0.503146 | Generator Loss: 5.556871
# 5/5 [==============================] - 5s 1s/step
# Epoch: 285 | Discriminator Loss: 0.503936 | Generator Loss: 4.642275
# 5/5 [==============================] - 5s 1s/step
# Epoch: 286 | Discriminator Loss: 0.505853 | Generator Loss: 4.119593
# 5/5 [==============================] - 5s 1s/step
# Epoch: 287 | Discriminator Loss: 0.503785 | Generator Loss: 6.251055
# 5/5 [==============================] - 5s 1s/step
# Epoch: 288 | Discriminator Loss: 0.504325 | Generator Loss: 4.936397
# 5/5 [==============================] - 5s 1s/step
# Epoch: 289 | Discriminator Loss: 0.504389 | Generator Loss: 4.753193
# 5/5 [==============================] - 5s 1s/step
# Epoch: 290 | Discriminator Loss: 0.502096 | Generator Loss: 5.370653
# 5/5 [==============================] - 5s 1s/step
# Epoch: 291 | Discriminator Loss: 0.505608 | Generator Loss: 4.022393
# 5/5 [==============================] - 5s 1s/step
# Epoch: 292 | Discriminator Loss: 0.505505 | Generator Loss: 4.834462
# 5/5 [==============================] - 5s 1s/step
# Epoch: 293 | Discriminator Loss: 0.503892 | Generator Loss: 4.402228
# 5/5 [==============================] - 5s 1s/step
# Epoch: 294 | Discriminator Loss: 0.504059 | Generator Loss: 4.391747
# 5/5 [==============================] - 5s 1s/step
# Epoch: 295 | Discriminator Loss: 0.505029 | Generator Loss: 4.031241
# 5/5 [==============================] - 5s 1s/step
# Epoch: 296 | Discriminator Loss: 0.502262 | Generator Loss: 5.606301
# 5/5 [==============================] - 5s 1s/step
# Epoch: 297 | Discriminator Loss: 0.502488 | Generator Loss: 4.706596
# 5/5 [==============================] - 5s 1s/step
# Epoch: 298 | Discriminator Loss: 0.503016 | Generator Loss: 4.747659
# 5/5 [==============================] - 5s 1s/step
# Epoch: 299 | Discriminator Loss: 0.503021 | Generator Loss: 4.828099
# 5/5 [==============================] - 5s 1s/step
# Epoch: 300 | Discriminator Loss: 0.501559 | Generator Loss: 5.055953
# 5/5 [==============================] - 5s 1s/step
# Epoch: 301 | Discriminator Loss: 0.501780 | Generator Loss: 5.873703
# 5/5 [==============================] - 5s 1s/step
# Epoch: 302 | Discriminator Loss: 0.501938 | Generator Loss: 5.104486
# 5/5 [==============================] - 5s 1s/step
# Epoch: 303 | Discriminator Loss: 0.503259 | Generator Loss: 4.914717
# 5/5 [==============================] - 5s 1s/step
# Epoch: 304 | Discriminator Loss: 0.502895 | Generator Loss: 5.788977
# 5/5 [==============================] - 5s 1s/step
# Epoch: 305 | Discriminator Loss: 0.502213 | Generator Loss: 5.198893
# 5/5 [==============================] - 5s 1s/step
# Epoch: 306 | Discriminator Loss: 0.503769 | Generator Loss: 4.414398
# 5/5 [==============================] - 5s 1s/step
# Epoch: 307 | Discriminator Loss: 0.500756 | Generator Loss: 8.573804
# 5/5 [==============================] - 5s 1s/step
# Epoch: 308 | Discriminator Loss: 0.500467 | Generator Loss: 7.018661
# 5/5 [==============================] - 5s 1s/step
# Epoch: 309 | Discriminator Loss: 0.500845 | Generator Loss: 6.302078
# 5/5 [==============================] - 5s 1s/step
# Epoch: 310 | Discriminator Loss: 0.501102 | Generator Loss: 5.720459
# 5/5 [==============================] - 5s 1s/step
# Epoch: 311 | Discriminator Loss: 0.501045 | Generator Loss: 6.593378
# 5/5 [==============================] - 5s 1s/step
# Epoch: 312 | Discriminator Loss: 0.500298 | Generator Loss: 7.320895
# 5/5 [==============================] - 5s 1s/step
# Epoch: 313 | Discriminator Loss: 0.500694 | Generator Loss: 5.989864
# 5/5 [==============================] - 5s 1s/step
# Epoch: 314 | Discriminator Loss: 0.500629 | Generator Loss: 5.860467
# 5/5 [==============================] - 5s 1s/step
# Epoch: 315 | Discriminator Loss: 0.501858 | Generator Loss: 5.371601
# 5/5 [==============================] - 5s 1s/step
# Epoch: 316 | Discriminator Loss: 0.502287 | Generator Loss: 7.331081
# 5/5 [==============================] - 5s 1s/step
# Epoch: 317 | Discriminator Loss: 0.500161 | Generator Loss: 9.035433
# 5/5 [==============================] - 5s 1s/step
# Epoch: 318 | Discriminator Loss: 0.500609 | Generator Loss: 6.460449
# 5/5 [==============================] - 5s 1s/step
# Epoch: 319 | Discriminator Loss: 0.500783 | Generator Loss: 5.836277
# 5/5 [==============================] - 5s 1s/step
# Epoch: 320 | Discriminator Loss: 0.500446 | Generator Loss: 8.588430
# 5/5 [==============================] - 5s 1s/step
# Epoch: 321 | Discriminator Loss: 0.500395 | Generator Loss: 7.198163
# 5/5 [==============================] - 5s 1s/step
# Epoch: 322 | Discriminator Loss: 0.500870 | Generator Loss: 6.003740
# 5/5 [==============================] - 5s 1s/step
# Epoch: 323 | Discriminator Loss: 0.500694 | Generator Loss: 6.265258
# 5/5 [==============================] - 5s 1s/step
# Epoch: 324 | Discriminator Loss: 0.500834 | Generator Loss: 6.244783
# 5/5 [==============================] - 5s 1s/step
# Epoch: 325 | Discriminator Loss: 0.501128 | Generator Loss: 5.615755
# 5/5 [==============================] - 5s 1s/step
# Epoch: 326 | Discriminator Loss: 0.500446 | Generator Loss: 6.754308
# 5/5 [==============================] - 5s 1s/step
# Epoch: 327 | Discriminator Loss: 0.500919 | Generator Loss: 6.343744
# 5/5 [==============================] - 5s 1s/step
# Epoch: 328 | Discriminator Loss: 0.501287 | Generator Loss: 5.586109
# 5/5 [==============================] - 5s 1s/step
# Epoch: 329 | Discriminator Loss: 0.501257 | Generator Loss: 5.825468
# 5/5 [==============================] - 5s 1s/step
# Epoch: 330 | Discriminator Loss: 0.500460 | Generator Loss: 6.813523
# 5/5 [==============================] - 5s 1s/step
# Epoch: 331 | Discriminator Loss: 0.501332 | Generator Loss: 5.473704
# 5/5 [==============================] - 5s 1s/step
# Epoch: 332 | Discriminator Loss: 0.501042 | Generator Loss: 5.559469
# 5/5 [==============================] - 5s 1s/step
# Epoch: 333 | Discriminator Loss: 0.500986 | Generator Loss: 7.626502
# 5/5 [==============================] - 5s 1s/step
# Epoch: 334 | Discriminator Loss: 0.500337 | Generator Loss: 7.168429
# 5/5 [==============================] - 5s 1s/step
# Epoch: 335 | Discriminator Loss: 0.500536 | Generator Loss: 6.067317
# 5/5 [==============================] - 5s 1s/step
# Epoch: 336 | Discriminator Loss: 0.500456 | Generator Loss: 5.888247
# 5/5 [==============================] - 5s 1s/step
# Epoch: 337 | Discriminator Loss: 0.500568 | Generator Loss: 6.412295
# 5/5 [==============================] - 5s 1s/step
# Epoch: 338 | Discriminator Loss: 0.501343 | Generator Loss: 6.121814
# 5/5 [==============================] - 5s 1s/step
# Epoch: 339 | Discriminator Loss: 0.500053 | Generator Loss: 10.980063
# 5/5 [==============================] - 5s 1s/step
# Epoch: 340 | Discriminator Loss: 0.500069 | Generator Loss: 9.669224
# 5/5 [==============================] - 5s 1s/step
# Epoch: 341 | Discriminator Loss: 0.500270 | Generator Loss: 7.291817
# 5/5 [==============================] - 5s 1s/step
# Epoch: 342 | Discriminator Loss: 0.501367 | Generator Loss: 5.561939
# 5/5 [==============================] - 5s 1s/step
# Epoch: 343 | Discriminator Loss: 0.501215 | Generator Loss: 6.853179
# 5/5 [==============================] - 5s 1s/step
# Epoch: 344 | Discriminator Loss: 0.500094 | Generator Loss: 8.597089
# 5/5 [==============================] - 5s 1s/step
# Epoch: 345 | Discriminator Loss: 0.500223 | Generator Loss: 7.138616
# 5/5 [==============================] - 5s 1s/step
# Epoch: 346 | Discriminator Loss: 0.500500 | Generator Loss: 6.550926
# 5/5 [==============================] - 5s 1s/step
# Epoch: 347 | Discriminator Loss: 0.500865 | Generator Loss: 6.560430
# 5/5 [==============================] - 5s 1s/step
# Epoch: 348 | Discriminator Loss: 0.500612 | Generator Loss: 6.640871
# 5/5 [==============================] - 5s 1s/step
# Epoch: 349 | Discriminator Loss: 0.500450 | Generator Loss: 7.216409
# 5/5 [==============================] - 5s 1s/step
# Epoch: 350 | Discriminator Loss: 0.501154 | Generator Loss: 5.811370
# 5/5 [==============================] - 5s 1s/step
# Epoch: 351 | Discriminator Loss: 0.501267 | Generator Loss: 5.157948
# 5/5 [==============================] - 5s 1s/step
# Epoch: 352 | Discriminator Loss: 0.500380 | Generator Loss: 15.683520
# 5/5 [==============================] - 5s 1s/step
# Epoch: 353 | Discriminator Loss: 0.500033 | Generator Loss: 12.850962
# 5/5 [==============================] - 5s 1s/step
# Epoch: 354 | Discriminator Loss: 0.500045 | Generator Loss: 10.405600
# 5/5 [==============================] - 5s 1s/step
# Epoch: 355 | Discriminator Loss: 0.500220 | Generator Loss: 8.223255
# 5/5 [==============================] - 5s 1s/step
# Epoch: 356 | Discriminator Loss: 0.500208 | Generator Loss: 7.757690
# 5/5 [==============================] - 5s 1s/step
# Epoch: 357 | Discriminator Loss: 0.500218 | Generator Loss: 7.991707
# 5/5 [==============================] - 5s 1s/step
# Epoch: 358 | Discriminator Loss: 0.500308 | Generator Loss: 7.367629
# 5/5 [==============================] - 5s 1s/step
# Epoch: 359 | Discriminator Loss: 0.500096 | Generator Loss: 8.984423
# 5/5 [==============================] - 5s 1s/step
# Epoch: 360 | Discriminator Loss: 0.500212 | Generator Loss: 7.288721
# 5/5 [==============================] - 5s 1s/step
# Epoch: 361 | Discriminator Loss: 0.500471 | Generator Loss: 8.274384
# 5/5 [==============================] - 5s 1s/step
# Epoch: 362 | Discriminator Loss: 0.500426 | Generator Loss: 6.724751
# 5/5 [==============================] - 5s 1s/step
# Epoch: 363 | Discriminator Loss: 0.500479 | Generator Loss: 7.337674
# 5/5 [==============================] - 5s 1s/step
# Epoch: 364 | Discriminator Loss: 0.500188 | Generator Loss: 7.998876
# 5/5 [==============================] - 5s 1s/step
# Epoch: 365 | Discriminator Loss: 0.500156 | Generator Loss: 7.725434
# 5/5 [==============================] - 5s 1s/step
# Epoch: 366 | Discriminator Loss: 0.500413 | Generator Loss: 7.043769
# 5/5 [==============================] - 5s 1s/step
# Epoch: 367 | Discriminator Loss: 0.500403 | Generator Loss: 6.661357
# 5/5 [==============================] - 5s 1s/step
# Epoch: 368 | Discriminator Loss: 0.500436 | Generator Loss: 6.825582
# 5/5 [==============================] - 5s 1s/step
# Epoch: 369 | Discriminator Loss: 0.500384 | Generator Loss: 6.237967
# 5/5 [==============================] - 5s 1s/step
# Epoch: 370 | Discriminator Loss: 0.500467 | Generator Loss: 5.980295
# 5/5 [==============================] - 5s 1s/step
# Epoch: 371 | Discriminator Loss: 0.500239 | Generator Loss: 8.458136
# 5/5 [==============================] - 5s 1s/step
# Epoch: 372 | Discriminator Loss: 0.500059 | Generator Loss: 9.080709
# 5/5 [==============================] - 5s 1s/step
# Epoch: 373 | Discriminator Loss: 0.500235 | Generator Loss: 7.800487
# 5/5 [==============================] - 5s 1s/step
# Epoch: 374 | Discriminator Loss: 0.500186 | Generator Loss: 7.434181
# 5/5 [==============================] - 5s 1s/step
# Epoch: 375 | Discriminator Loss: 0.500198 | Generator Loss: 7.037189
# 5/5 [==============================] - 5s 1s/step
# Epoch: 376 | Discriminator Loss: 0.500469 | Generator Loss: 7.464625
# 5/5 [==============================] - 5s 1s/step
# Epoch: 377 | Discriminator Loss: 0.500087 | Generator Loss: 8.943491
# 5/5 [==============================] - 5s 1s/step
# Epoch: 378 | Discriminator Loss: 0.500260 | Generator Loss: 7.562973
# 5/5 [==============================] - 5s 1s/step
# Epoch: 379 | Discriminator Loss: 0.500345 | Generator Loss: 6.995267
# 5/5 [==============================] - 5s 1s/step
# Epoch: 380 | Discriminator Loss: 0.500391 | Generator Loss: 6.960368
# 5/5 [==============================] - 5s 1s/step
# Epoch: 381 | Discriminator Loss: 0.500314 | Generator Loss: 8.203779
# 5/5 [==============================] - 5s 1s/step
# Epoch: 382 | Discriminator Loss: 0.500241 | Generator Loss: 12.303743
# 5/5 [==============================] - 5s 1s/step
# Epoch: 383 | Discriminator Loss: 0.500024 | Generator Loss: 10.520432
# 5/5 [==============================] - 5s 1s/step
# Epoch: 384 | Discriminator Loss: 0.500115 | Generator Loss: 8.625275
# 5/5 [==============================] - 5s 1s/step
# Epoch: 385 | Discriminator Loss: 0.500227 | Generator Loss: 7.137639
# 5/5 [==============================] - 5s 1s/step
# Epoch: 386 | Discriminator Loss: 0.500318 | Generator Loss: 7.155531
# 5/5 [==============================] - 5s 1s/step
# Epoch: 387 | Discriminator Loss: 0.500300 | Generator Loss: 6.912331
# 5/5 [==============================] - 5s 1s/step
# Epoch: 388 | Discriminator Loss: 0.500380 | Generator Loss: 13.706889
# 5/5 [==============================] - 5s 1s/step
# Epoch: 389 | Discriminator Loss: 0.500277 | Generator Loss: 6.468536
# 5/5 [==============================] - 5s 1s/step
# Epoch: 390 | Discriminator Loss: 0.500319 | Generator Loss: 6.907272
# 5/5 [==============================] - 5s 1s/step
# Epoch: 391 | Discriminator Loss: 0.500400 | Generator Loss: 6.237936
# 5/5 [==============================] - 5s 1s/step
# Epoch: 392 | Discriminator Loss: 0.500313 | Generator Loss: 9.479383
# 5/5 [==============================] - 5s 1s/step
# Epoch: 393 | Discriminator Loss: 0.500019 | Generator Loss: 11.098727
# 5/5 [==============================] - 5s 1s/step
# Epoch: 394 | Discriminator Loss: 0.500043 | Generator Loss: 9.519244
# 5/5 [==============================] - 5s 1s/step
# Epoch: 395 | Discriminator Loss: 0.500072 | Generator Loss: 8.441990
# 5/5 [==============================] - 5s 1s/step
# Epoch: 396 | Discriminator Loss: 0.500150 | Generator Loss: 7.643867
# 5/5 [==============================] - 5s 1s/step
# Epoch: 397 | Discriminator Loss: 0.500209 | Generator Loss: 7.839319
# 5/5 [==============================] - 5s 1s/step
# Epoch: 398 | Discriminator Loss: 0.500173 | Generator Loss: 7.486646
# 5/5 [==============================] - 5s 1s/step
# Epoch: 399 | Discriminator Loss: 0.500173 | Generator Loss: 7.763152
# 5/5 [==============================] - 5s 1s/step
# Epoch: 400 | Discriminator Loss: 0.500118 | Generator Loss: 9.453545
# 5/5 [==============================] - 5s 1s/step
# Epoch: 401 | Discriminator Loss: 0.500157 | Generator Loss: 8.236795
# 5/5 [==============================] - 5s 1s/step
# Epoch: 402 | Discriminator Loss: 0.500317 | Generator Loss: 7.762000
# 5/5 [==============================] - 5s 1s/step
# Epoch: 403 | Discriminator Loss: 0.500297 | Generator Loss: 7.555401
# 5/5 [==============================] - 5s 1s/step
# Epoch: 404 | Discriminator Loss: 0.500264 | Generator Loss: 7.444519
# ...
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2369 | Discriminator Loss: 0.500000 | Generator Loss: 18.344835
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2370 | Discriminator Loss: 0.500000 | Generator Loss: 18.325577
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2371 | Discriminator Loss: 0.500000 | Generator Loss: 18.410967
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2372 | Discriminator Loss: 0.500000 | Generator Loss: 18.544727
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2373 | Discriminator Loss: 0.500000 | Generator Loss: 18.459616
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2374 | Discriminator Loss: 0.500000 | Generator Loss: 18.390598
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2375 | Discriminator Loss: 0.500000 | Generator Loss: 18.424679
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2376 | Discriminator Loss: 0.500000 | Generator Loss: 18.433218
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2377 | Discriminator Loss: 0.500000 | Generator Loss: 18.451096
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2378 | Discriminator Loss: 0.500000 | Generator Loss: 18.428486
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2379 | Discriminator Loss: 0.500000 | Generator Loss: 18.460117
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2380 | Discriminator Loss: 0.500000 | Generator Loss: 18.413330
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2381 | Discriminator Loss: 0.500000 | Generator Loss: 18.336527
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2382 | Discriminator Loss: 0.500000 | Generator Loss: 18.304523
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2383 | Discriminator Loss: 0.500000 | Generator Loss: 18.313908
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2384 | Discriminator Loss: 0.500000 | Generator Loss: 18.320171
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2385 | Discriminator Loss: 0.500000 | Generator Loss: 18.376766
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2386 | Discriminator Loss: 0.500000 | Generator Loss: 18.453419
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2387 | Discriminator Loss: 0.500000 | Generator Loss: 18.473013
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2388 | Discriminator Loss: 0.500000 | Generator Loss: 18.505579
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2389 | Discriminator Loss: 0.500000 | Generator Loss: 18.526762
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2390 | Discriminator Loss: 0.500000 | Generator Loss: 18.539825
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2391 | Discriminator Loss: 0.500000 | Generator Loss: 18.582085
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2392 | Discriminator Loss: 0.500000 | Generator Loss: 18.624947
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2393 | Discriminator Loss: 0.500000 | Generator Loss: 18.665209
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2394 | Discriminator Loss: 0.500000 | Generator Loss: 18.703928
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2395 | Discriminator Loss: 0.500000 | Generator Loss: 18.736454
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2396 | Discriminator Loss: 0.500000 | Generator Loss: 18.773489
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2397 | Discriminator Loss: 0.500000 | Generator Loss: 18.807911
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2398 | Discriminator Loss: 0.500000 | Generator Loss: 18.942503
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2399 | Discriminator Loss: 0.500000 | Generator Loss: 19.010174
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2400 | Discriminator Loss: 0.500000 | Generator Loss: 18.896664
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2401 | Discriminator Loss: 0.500000 | Generator Loss: 19.075230
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2402 | Discriminator Loss: 0.500000 | Generator Loss: 18.620941
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2403 | Discriminator Loss: 0.500000 | Generator Loss: 18.331778
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2404 | Discriminator Loss: 0.500000 | Generator Loss: 18.855143
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2405 | Discriminator Loss: 0.500000 | Generator Loss: 20.021851
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2406 | Discriminator Loss: 0.500000 | Generator Loss: 18.690620
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2407 | Discriminator Loss: 0.500000 | Generator Loss: 18.645000
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2408 | Discriminator Loss: 0.500000 | Generator Loss: 17.564028
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2409 | Discriminator Loss: 0.500000 | Generator Loss: 17.371723
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2410 | Discriminator Loss: 0.500000 | Generator Loss: 17.003372
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2411 | Discriminator Loss: 0.500000 | Generator Loss: 17.708752
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2412 | Discriminator Loss: 0.500000 | Generator Loss: 16.461239
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2413 | Discriminator Loss: 0.500000 | Generator Loss: 16.240993
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2414 | Discriminator Loss: 0.500000 | Generator Loss: 16.689716
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2415 | Discriminator Loss: 0.500000 | Generator Loss: 16.910227
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2416 | Discriminator Loss: 0.500000 | Generator Loss: 16.565422
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2417 | Discriminator Loss: 0.500000 | Generator Loss: 16.577801
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2418 | Discriminator Loss: 0.500000 | Generator Loss: 17.526836
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2419 | Discriminator Loss: 0.500000 | Generator Loss: 17.073910
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2420 | Discriminator Loss: 0.500000 | Generator Loss: 17.515156
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2421 | Discriminator Loss: 0.500000 | Generator Loss: 17.032434
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2422 | Discriminator Loss: 0.500000 | Generator Loss: 16.687759
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2423 | Discriminator Loss: 0.500000 | Generator Loss: 16.760044
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2424 | Discriminator Loss: 0.500000 | Generator Loss: 16.534801
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2425 | Discriminator Loss: 0.500000 | Generator Loss: 16.577841
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2426 | Discriminator Loss: 0.500000 | Generator Loss: 16.710423
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2427 | Discriminator Loss: 0.500000 | Generator Loss: 16.647999
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2428 | Discriminator Loss: 0.500000 | Generator Loss: 16.884726
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2429 | Discriminator Loss: 0.500000 | Generator Loss: 17.197783
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2430 | Discriminator Loss: 0.500000 | Generator Loss: 17.496971
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2431 | Discriminator Loss: 0.500000 | Generator Loss: 18.775417
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2432 | Discriminator Loss: 0.500000 | Generator Loss: 18.509586
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2433 | Discriminator Loss: 0.500000 | Generator Loss: 18.287695
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2434 | Discriminator Loss: 0.500000 | Generator Loss: 18.049297
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2435 | Discriminator Loss: 0.500000 | Generator Loss: 17.880821
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2436 | Discriminator Loss: 0.500000 | Generator Loss: 18.401232
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2437 | Discriminator Loss: 0.500000 | Generator Loss: 18.225193
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2438 | Discriminator Loss: 0.500000 | Generator Loss: 17.307728
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2439 | Discriminator Loss: 0.500000 | Generator Loss: 16.854517
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2440 | Discriminator Loss: 0.500000 | Generator Loss: 17.037334
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2441 | Discriminator Loss: 0.500000 | Generator Loss: 17.637094
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2442 | Discriminator Loss: 0.500000 | Generator Loss: 17.883343
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2443 | Discriminator Loss: 0.500000 | Generator Loss: 16.428303
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2444 | Discriminator Loss: 0.500000 | Generator Loss: 16.690424
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2445 | Discriminator Loss: 0.500000 | Generator Loss: 16.857090
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2446 | Discriminator Loss: 0.500000 | Generator Loss: 16.880550
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2447 | Discriminator Loss: 0.500000 | Generator Loss: 17.185881
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2448 | Discriminator Loss: 0.500000 | Generator Loss: 17.707973
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2449 | Discriminator Loss: 0.500000 | Generator Loss: 17.485109
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2450 | Discriminator Loss: 0.500000 | Generator Loss: 16.933422
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2451 | Discriminator Loss: 0.500000 | Generator Loss: 17.073397
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2452 | Discriminator Loss: 0.500000 | Generator Loss: 17.067112
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2453 | Discriminator Loss: 0.500000 | Generator Loss: 17.241625
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2454 | Discriminator Loss: 0.500000 | Generator Loss: 17.423029
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2455 | Discriminator Loss: 0.500000 | Generator Loss: 17.395426
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2456 | Discriminator Loss: 0.500000 | Generator Loss: 17.226267
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2457 | Discriminator Loss: 0.500000 | Generator Loss: 17.029743
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2458 | Discriminator Loss: 0.500000 | Generator Loss: 17.117649
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2459 | Discriminator Loss: 0.500000 | Generator Loss: 17.364023
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2460 | Discriminator Loss: 0.500000 | Generator Loss: 17.356253
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2461 | Discriminator Loss: 0.500000 | Generator Loss: 17.565445
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2462 | Discriminator Loss: 0.500000 | Generator Loss: 17.820255
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2463 | Discriminator Loss: 0.500000 | Generator Loss: 17.855782
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2464 | Discriminator Loss: 0.500000 | Generator Loss: 17.923187
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2465 | Discriminator Loss: 0.500000 | Generator Loss: 18.720423
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2466 | Discriminator Loss: 0.500000 | Generator Loss: 19.438654
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2467 | Discriminator Loss: 0.500000 | Generator Loss: 18.743797
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2468 | Discriminator Loss: 0.500000 | Generator Loss: 18.405964
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2469 | Discriminator Loss: 0.500000 | Generator Loss: 18.002048
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2470 | Discriminator Loss: 0.500000 | Generator Loss: 17.920893
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2471 | Discriminator Loss: 0.500000 | Generator Loss: 17.550871
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2472 | Discriminator Loss: 0.500000 | Generator Loss: 17.458151
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2473 | Discriminator Loss: 0.500000 | Generator Loss: 17.882561
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2474 | Discriminator Loss: 0.500000 | Generator Loss: 17.735464
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2475 | Discriminator Loss: 0.500000 | Generator Loss: 17.819691
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2476 | Discriminator Loss: 0.500000 | Generator Loss: 17.975353
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2477 | Discriminator Loss: 0.500000 | Generator Loss: 17.451244
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2478 | Discriminator Loss: 0.500000 | Generator Loss: 17.306355
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2479 | Discriminator Loss: 0.500000 | Generator Loss: 17.235554
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2480 | Discriminator Loss: 0.500000 | Generator Loss: 17.190716
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2481 | Discriminator Loss: 0.500000 | Generator Loss: 17.057020
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2482 | Discriminator Loss: 0.500000 | Generator Loss: 17.333612
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2483 | Discriminator Loss: 0.500000 | Generator Loss: 17.108429
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2484 | Discriminator Loss: 0.500000 | Generator Loss: 16.915827
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2485 | Discriminator Loss: 0.500000 | Generator Loss: 17.042313
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2486 | Discriminator Loss: 0.500000 | Generator Loss: 16.987503
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2487 | Discriminator Loss: 0.500000 | Generator Loss: 17.050217
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2488 | Discriminator Loss: 0.500000 | Generator Loss: 17.132366
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2489 | Discriminator Loss: 0.500000 | Generator Loss: 17.303904
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2490 | Discriminator Loss: 0.500000 | Generator Loss: 17.324295
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2491 | Discriminator Loss: 0.500000 | Generator Loss: 17.169262
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2492 | Discriminator Loss: 0.500000 | Generator Loss: 17.220247
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2493 | Discriminator Loss: 0.500000 | Generator Loss: 17.226105
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2494 | Discriminator Loss: 0.500000 | Generator Loss: 17.178856
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2495 | Discriminator Loss: 0.500000 | Generator Loss: 17.251270
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2496 | Discriminator Loss: 0.500000 | Generator Loss: 17.164099
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2497 | Discriminator Loss: 0.500000 | Generator Loss: 17.220942
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2498 | Discriminator Loss: 0.500000 | Generator Loss: 17.301483
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2499 | Discriminator Loss: 0.500000 | Generator Loss: 17.317656
# 5/5 [==============================] - 5s 1s/step
# Epoch: 2500 | Discriminator Loss: 0.500000 | Generator Loss: 17.188793

# %% [markdown]
# ### Generating Samples and Analysis
#
# - Plot your discriminator and generator losses and explain how it represents the MiniMax game in play, and comment on the trends you observe.
# - Generate random 5 noise samples and their corresponding fake images.
# - Mention if you observe any failure modes
# - **BONUS (5%):** Try generating some good samples, and try interpolating the input noise samples (Vector Arithmetic) to see if the results are as expected.

# %%
def plot_loss(gen_loss,disc_loss):
    plt.plot(gen_loss)
    plt.plot(disc_loss)
    plt.title('GAN Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Generator', 'Discriminator'], loc='upper left')
    plt.grid()
    plt.show()

# %%
plot_loss(gen_loss, disc_loss)

# %%
test_gen = build_generator()
test_gen.load_weights(os.path.join(BASE_DIR,'generator'))
output = test_gen.predict(sample_noise())
plt.imshow(output[0,:,:,:])
plt.figure()
plt.imshow(output[1,:,:,:])
plt.figure()
plt.imshow(output[2,:,:,:])
plt.figure()
plt.imshow(output[3,:,:,:])
plt.figure()
plt.imshow(output[4,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Analysis
#
# We can see that a mode collapse has occured leading to the generator producing one kind of image for all noise samples. This belief is further backed by the loss plot which is oscilating over time indicating a jump from one mode to another. At certain periods, the generator sees a drop in the loss, this is when it jumps between modes that have different losses. The generator eventually keeps outputting noise that could resemble highly pixelated emojis however the discriminator is able to identify them mostly as fake images which leads to the very low loss value of the discriminator. Finally, with regards to the minmax game at play, it can only really be observed in the earlier epochs (< 200). We see over here that an decrease in the loss value of the generator sees an increase in the loss of the discriminator and vice versa, since both of these components are competing against each other in a zero sum game.

# %% [markdown]
# ## PART 2: Stablizing GANs
#
# In the first part, we trained our GAN using the standard methods proposed initially. In this part we will tweak our models and our training loop based on suggestions that deep learning researchers have come up with through their experiences. We will see if we encountered into typical problems faced while training GANs and see if these proposed methods improve our GANs and resolve issuse previously faced.

# %% [markdown]
# We have already implemented a GAN based on the recommendations made by Alec Radford, et al. in the 2015 paper titled [“Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks.”](https://arxiv.org/abs/1511.06434)
#
#
#
# We have:
# 1. Downsampled using strided convolutions
# 2. Upsampled using strided convolutions
# 3. Used LeakyReLu in our discriminator, and ReLu in the generator and Tanh for the output of the generator.
# 4. Used BatchNormalization in both the discriminator and generator.

# %% [markdown]
# In addition to these, we will also make use of some more tips from the aforementioned paper, as well as tips from Soumith Chintala, who is one of the co-authors of the DCGAN paper in his [NIPS presentation](https://www.youtube.com/watch?v=X1mUN6dD8uE)

# %% [markdown]
# ### Modifications in the Models
#
# Here are some suggested modifications in the generator and discriminator models:
#
# - Use LeakyReLu in BOTH the generator and discriminator
# - Use Gaussian Weight initialization with mean=0 and std = 0.02. (Use the imported RandomNormal function to get weights and pass it in as the kernel_initializer argument in a convolutional layer)
# - Use Adam optimizer
#
# Make these modifications in your generator and discriminator models.

# %%
def build_discriminator():
    input_disc = Input(shape=(64,64,3), name='input_disc')
    conv_1 = Conv2D(64, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False, kernel_initializer=RandomNormal(stddev=0.02))(input_disc)
    leak_rel_1 = LeakyReLU()(conv_1)
    conv_2 = Conv2D(128, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_1)
    BN_1 = BatchNormalization()(conv_2)
    leak_rel_2 = LeakyReLU()(BN_1)
    conv_3 = Conv2D(256, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_2)
    BN_2 = BatchNormalization()(conv_3)
    leak_rel_3 = LeakyReLU()(BN_2)
    conv_4 = Conv2D(512, kernel_size=(4,4), strides=(2,2), padding='same', use_bias=False)(leak_rel_3)
    BN_3 = BatchNormalization()(conv_4)
    leak_rel_4 = LeakyReLU()(BN_3)
    conv_5 = Conv2D(1, kernel_size=(3,3), padding='same', use_bias=False)(leak_rel_4)
    flatten_disc = Flatten()(conv_5)
    output_disc = Dense(1, activation='sigmoid')(flatten_disc)
    disc = Model(inputs=input_disc, outputs=output_disc)
    return disc

# %%
def build_generator():
    input_gen = Input(shape=(100,), name='input_gen')
    dense_1 = Dense(4*4*1024)(input_gen)
    Reshape_1 = Reshape((4,4,1024),)(dense_1)
    conv_1 = Conv2DTranspose(512, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, kernel_initializer=RandomNormal(stddev=0.02))(Reshape_1)
    leak_rel_1 = LeakyReLU()(conv_1)
    conv_2 = Conv2DTranspose(256, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False)(leak_rel_1)
    leak_rel_2 = LeakyReLU()(conv_2)
    conv_3 = Conv2DTranspose(128, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False)(leak_rel_2)
    leak_rel_3 = LeakyReLU()(conv_3)
    conv_4 = Conv2DTranspose(3, kernel_size=(5,5), strides=(2,2), padding='same', use_bias=False, activation='tanh')(leak_rel_3)
    output_gen = Model(inputs = input_gen, outputs=conv_4)
    return output_gen

# %% [markdown]
# ### Scale Images to the Range [-1,1]
# We already know that normalizing images improves training for any model. We will scale our images in the range [-1,1] since we are using a tanh activation in our generator. This will make the fake generated images and real images in the same range and will enable our discriminator to learn better.
# Implement the following function to normalize a numpy array containing images. **Note:** The images will be in the range [0,255]

# %%
def normalize(images):
    images = images.astype('float32')
    images = (images - 127.5) / 127.5
    return images

# %%
sample = load_data()
norm = normalize(sample[0:5])
print(norm[3])

# %% [markdown]
# ### Use Gaussian Latent Space
# Previously we have been using a uniform distribution to sample a latent space as recommended in the DCGAN paper, but more recently researchers suggest to use a Standard Gaussian distribution to sample the latent space. Modify the <code>sample_noise</code> function to sample fomr a Gaussian distribution.

# %%
def sample_noise():
    return np.reshape(np.random.normal(size=(NOISE_DIM * BATCH_SIZE)),(BATCH_SIZE,NOISE_DIM))

# %% [markdown]
# ### Use Label Smoothing
# Normally, we use hard labels 1s and 0s to train our GANs. Researchers have suggested to smooth labels and use "soft" labels . This is said to have a "regularizing" effect on the training.

# %% [markdown]
# #### Real Label Smoothing
# For Real labels, i.e. 1s, we will smooth the labels uniformly between [0.7,1.2]. Use np.random.random for this.

# %%
def smooth_real_labels(y):
    return y-0.3+(np.random.random(y.shape)*0.5)

# %% [markdown]
# #### Fake Label Smoothing

# %%
def smooth_fake_labels(y):
    return y+np.random.random(y.shape)*0.3

# %% [markdown]
# We will make use of these functions later in our training loop.

# %% [markdown]
# ### Train Discriminator with Real and Fake Images separately
# Previously we were combining our fake and real images batches and doing one update to our discriminator. Researchers suggest that the best practice is to train our discriminator in two updates, one for the real images and one for the fake images.

# %% [markdown]
# ### Flip some labels randomly while training the Generator
# Soumith Chintala also suggests that in practice, ocassionally flipping the labels of the generator may help (Swapping Real and Fake)

# %% [markdown]
# ### Modified Training Loop
#
# Incorporate the above mentioned suggestions in your training process. You don't have to apply all of them. See which combination works best for you. Mention the methods you made use of.

# %%
def noisy_labels(y):
	flip_index = np.random.choice([i for i in range(y.shape[0])], size=int(0.05 * y.shape[0]))
	y[flip_index] = 1-y[flip_index]
	return y

# %%
def gan_training_loop(intervals=200):
    # Setup Models here
    gen = build_generator()
    disc = build_discriminator()
    # gen.compile(optimizer=Adam(lr=0.001, beta_1=0.5), loss='binary_crossentropy')
    GAN = build_gan(gen, disc)
    disc.trainable = True
    disc.compile(optimizer=Adam(lr=0.0002, beta_1=0.5), loss='binary_crossentropy', metrics=['accuracy'])
    
    # Load Data
    X_train = load_data()
    X_train = normalize(X_train)
    total_size = X_train.shape[0]
    indices = np.arange(0,total_size ,BATCH_SIZE)
    all_disc_loss = []
    all_gen_loss = []
    if total_size % BATCH_SIZE:
        indices = indices[:-1]
    
    # Start Training Loop
    for e in range(EPOCHS):
        progress_bar = Progbar(target=len(indices))
        np.random.shuffle(indices)
        epoch_gen_loss = []
        epoch_disc_loss = []

        # Train on Batch
        for i,index in enumerate(indices):
            # Write your code here
            fake_images = gen.predict(sample_noise())
            real_images = X_train[index:index+BATCH_SIZE]
            
            D_loss_real = disc.train_on_batch(real_images, smooth_real_labels(np.ones((BATCH_SIZE, 1))))
            D_loss_fake = disc.train_on_batch(fake_images, noisy_labels(smooth_fake_labels(np.zeros((BATCH_SIZE, 1)))))
            
            if not (e % intervals):
                save_samples(fake_images,e)
                
            # If you are training the discriminator in two updates, uncomment this
            disc_loss = 0.5 * np.add(D_loss_real, D_loss_fake)
            epoch_disc_loss.append(disc_loss)
            
            disc.trainable = False
            noise = sample_noise()
            labels = smooth_real_labels(np.ones((BATCH_SIZE, 1)))
            gen_loss = GAN.train_on_batch(noise, labels)
            disc.trainable = True
            epoch_gen_loss.append(gen_loss)
            progress_bar.update(i+1)
        if not (e%intervals):
            disc.save_weights(os.path.join(BASE_DIR,'discriminator'),True)
            gen.save_weights(os.path.join(BASE_DIR,'generator'),True)
            
        avg_epoch_disc_loss = np.array(epoch_disc_loss).mean()
        avg_epoch_gen_loss = np.array(epoch_gen_loss).mean()
        all_disc_loss.append(avg_epoch_disc_loss)
        all_gen_loss.append(avg_epoch_gen_loss)
        print("Epoch: %d | Discriminator Loss: %f | Generator Loss: %f" % (e+1,avg_epoch_disc_loss,avg_epoch_gen_loss))
    return all_disc_loss,all_gen_loss

# %%
disc_loss, gen_loss = gan_training_loop(100)

# %% [markdown]
# ### Analysis
# Repeat the above analysis and mention changes you observed in terms of training and quality of fake images

# %%
plot_loss(gen_loss, disc_loss)

# %%
test_gen = build_generator()
test_gen.load_weights(os.path.join(BASE_DIR,'generator'))
output = test_gen.predict(sample_noise())
plt.imshow(output[0,:,:,:])
plt.figure()
plt.imshow(output[1,:,:,:])
plt.figure()
plt.imshow(output[2,:,:,:])
plt.figure()
plt.imshow(output[3,:,:,:])
plt.figure()
plt.imshow(output[4,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Analysis
# The first notable change was in the training time. The time it took to train the GAN decreased by 2 seconds per epoch. This could be due to the normalization of the images before the training loop began. Furthermore, it was noted that the loss for the generator stayed very close to 1~2 throughout the training as opposed to the previous model where it would have much higher values. Speaking of Generator loss, we can still see the oscilation of the generator loss, but these are very small variations and if we see the discriminator loss it also follows the same variation rather than staying close to one absolute value. The large peaks in the generator loss could be from jumping to another mode which is why in these instances the discriminator also sees a jump in it's loss. Finally, the quality of the generated images is much better this time. At the very least, some figure resembling emojis are generated but usually with distorted faces. The generator also interpolates some emojis into one combined figure for example in the 4th image above, the generator is caught trying to generate an emoji that is both a male and a female. There was also a failure mode around the 1700th epoch where the generator tries to generate the same distorted emoji that has a crooked smile. However, overall we can see that these modifications have done well to boost the performance of our GAN.
# Reference: https://machinelearningmastery.com/how-to-code-generative-adversarial-network-hacks/

# %% [markdown]
# ## BONUS - 10%
# The current training set was a subset of the actual emojis dataset. In the filtering process, most inanimate objects were removed and the focus was on front-facing emojis. Train the model over the full dataset or a subset of your choice and repeat the above analysis
